# %% [markdown]
# ## 4.1
#
# 通过`next()`函数手动遍历迭代器对象。
#
# ## 4.2
#
# 在自定义容器中，通过`__iter__()`可以将迭代行为委托给容器中的可迭代对象`list`、`tuple`或`set`处理。
#
# ## 4.3
#
# 通过生成器函数创建新的迭代模式。
#
# ## 4.4
#
# 通过实现迭代器协议创建迭代模式。
#
# 实现迭代器类的`__iter__()`方法，将其重写为一个生成器函数。
#
# ## 4.5
#
# `reversed()`与`__reversed__()`
#
# ## 4.6
#
# 创建包含额外信息的生成器函数。
#
# 自定义一个迭代器对象，重写迭代器类的`__iter__()`方法作为生成器函数。通过迭代器对象中的属性值来保存迭代过程中额外数据信息。
#
# 生成器函数并不需要一定是一个函数，也可以是迭代器对象中的`__iter__()`方法。
#
# ## 4.7 迭代器切片
#
# `itertools.islice()`
#
# ## 4.8
#
# `itertools.dropwhile()`
#
# ## 4.9
#
# `itertools.permutations()`
#
# ## 4.10
#
# `enumerate()`
#
# ## 4.11
#
# 同步迭代多个可迭代序列。
#
# `zip()` / `itertools.zip_longest()`
#
# ## 4.12
#
# 将多个可迭代序列串联起来进行迭代。
#
# `itertools.chain()`
#
# ## 4.13
#
# 数据处理管道。
#
# ## 4.14
#
# 通过`yield from`创建一个递归生成器函数，将一个嵌套序列展开。
#
# `yield from`在协程与基于生成器的并发中发挥着重要的作用。
#
# PEP380_Delegating_to_Subgenerator
#
# ## 4.15
#
# 遍历若干有序的可迭代序列，要求遍历结果仍然有序。
#
# `heapq.merge()`
#
# ## 4.16
#
# 使用迭代器替换无限`while`循环。
#
# `iter()`函数可接受一个形参参数列表为空的可调用对象，以及一个终止哨兵值作为参数。其创建一个迭代器，反复执行该可迭代对象，直到其返回值为终止哨兵值为止。
